# %%
from __future__ import annotations
from pathlib import Path
import mlflow

ROOT = Path.cwd().resolve().parents[0]
print(f"Root directory: {ROOT}")
mlflow.log_artifact(local_path=str(ROOT/"configs"/"config.yaml"), artifact_path="config")
# Out:
# Root directory: C:\Users\camer\projects\ev_load_fc

# %%
import mlflow
print(mlflow.get_tracking_uri())
# Out:
# sqlite:///mlflow.db

# %%
import os

# Print the current user
print("Current User:", os.getlogin())
# Out:
# Current User: camer

# %%
import os

# Print the user profile directory
print("User Profile Directory:", os.environ.get('USERPROFILE'))
# Out:
# User Profile Directory: C:\Users\camer

# %%
import xgboost as xgb
print(xgb.__version__)  # Check if GPU is supported in your version
# Out:
# 3.1.2

# %%
xgb.rabit.get_rank()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 xgb.rabit.get_rank()
#
# AttributeError: module 'xgboost' has no attribute 'rabit'
